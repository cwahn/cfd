# %%
import pickle
import matplotlib.pyplot as plt

data_path = "/home/ubuntu/openfoam/OpenFOAM/openfoam-v2212/run/dataGen/output10/14.863052612758228-10-360-186.62288836164478-235.91329451106708.data0"

# %%
from openfoam.train import read_data

data = read_data(data_path)

print(data[0])
print(data[1].shape)
# Out:
# 14.863052612758228
# (5, 256, 128, 256)

# %%
plt.imshow(data[1][2, :, 10, :])
